# %% [markdown]
# # Projeto 2 - Classificador Automático de Sentimento
#
# Você foi contratado por uma empresa parar analisar como os clientes estão reagindo a um determinado produto no Twitter. A empresa deseja que você crie um programa que irá analisar as mensagens disponíveis e classificará como "relevante" ou "irrelevante". Com isso ela deseja que mensagens negativas, que denigrem o nome do produto, ou que mereçam destaque, disparem um foco de atenção da área de marketing.<br /><br />
# Como aluno de Ciência dos Dados, você lembrou do Teorema de Bayes, mais especificamente do Classificador Naive-Bayes, que é largamente utilizado em filtros anti-spam de e-mails. O classificador permite calcular qual a probabilidade de uma mensagem ser relevante dadas as palavras em seu conteúdo.<br /><br />
# Para realizar o MVP (*minimum viable product*) do projeto, você precisa implementar uma versão do classificador que "aprende" o que é relevante com uma base de treinamento e compara a performance dos resultados com uma base de testes.<br /><br />
# Após validado, o seu protótipo poderá também capturar e classificar automaticamente as mensagens da plataforma.
#
# ## Informações do Projeto
#
# Prazo: 13/Set até às 23:59.<br />
# Grupo: 2 pessoas.<br /><br />
# Entregáveis via GitHub:
# * Arquivo notebook com o código do classificador, seguindo as orientações abaixo.
# * Arquivo Excel com as bases de treinamento e teste totalmente classificado.
#
# **NÃO disponibilizar o arquivo com os *access keys/tokens* do Twitter.**
#
#
# ### Check 3:
#
# Até o dia 06 de Setembro às 23:59, o notebook e o xlsx devem estar no Github com as seguintes evidências:
#     * Conta no twitter criada.
#     * Produto escolhido.
#     * Arquivo Excel contendo a base de treinamento e teste já classificado.
#
#
# Sugestão de leitura:<br />
# http://docs.tweepy.org/en/v3.5.0/index.html<br />
# https://monkeylearn.com/blog/practical-explanation-naive-bayes-classifier/

# %%
import math
import os.path
import pandas as pd
import json
from random import shuffle

# %% [markdown]
# ___
# ## Classificando as Mensagens
#
# Agora você deve abrir o arquivo Excel com as mensagens capturadas e classificar na Coluna B se a mensagem é relevante ou não.<br />
# Não se esqueça de colocar um nome para a coluna na célula **B1**.<br /><br />
# Fazer o mesmo na planilha de Controle.
#
# ___
# ## Montando o Classificador Naive-Bayes
#
# Com a base de treinamento montada, comece a desenvolver o classificador. Escreva o seu código abaixo:
#
# Opcionalmente:
# * Limpar as mensagens removendo os caracteres: enter, :, ", ', (, ), etc. Não remover emojis.<br />
# * Corrigir separação de espaços entre palavras e/ou emojis.
# * Propor outras limpezas/transformações que não afetem a qualidade da informação.

# %%
#dados = pd.read_excel('bobs.xlsx')
tudo = pd.ExcelFile('bobs.xlsx')
dados = pd.read_excel(tudo, 'Treinamento')
teste = pd.read_excel(tudo, 'Teste')

# %%
for i in range(len(dados)):
    caract=[',',';','.','!','?',"(",")", ':', '"', "'"]
    palavras = dados.Treinamento[i].split()
    palavrascerto=[]
    final=[]
    for x in palavras:
        lista=[]
        for a in range(len(x)):
            lista.append(x[a])
            
        palavrascerto.append(lista)
    for z in palavrascerto:
        for w in z:
            if w in caract:

                d=z.index(w)
                z[d] = ' '
    for q in range(len(palavrascerto)):
        junto = ''.join(palavrascerto[q])
        if len(junto)!=0:
            if junto[0] !='@' and junto[0:5]!='https' and junto!= 'rt' and junto[0:3]!='kkk':
                final.append(junto)
    deletar=[]            
    for a in range(len(final)):
        if final[a]=='de'and final[a+1]=='bobs':
            deletar.append(a)
    for m in deletar:
        del final[m]
        final[m]='debobs'    
    
            
            
            
    dados.Treinamento[i] = ' '.join(final)


dados.head(36)
# Out:
#                                           Treinamento relevancia
# 0                              bobs é mt ruim  mc&gt           r
# 1   sonhei com a namorada ideal   rolê  kunk  bobs...          r
# 2        peguei vários cupuns do bobs no jornal metro          i
# 3   trabalhei no bobs e carrefour quando mlk e foi...          i
# 4                 tô matando por um milkshake do bobs          r
# 5   a gnt toma um cafézin vai no bobs compra 770ml...          r
# 6                 vem me buscar hj q te dou um bobs 😍          r
# 7   oxe  é só marcar presença lá em alguma festinh...          i
# 8        eu queria um milkshake de ovomaltine do bobs          r
# 9   fui no bobs secão  quando cheguei lá tava fechado          i
# 10  fica a dúvida  comprar um milkshake no bobs ou...          r
# 11  as vezes tudo que uma pessoa precisa eh de um ...          r
# 12         esse milkshake do bobs é o melhor do mundo          r
# 13                     paramos aqui no bobs pra comer          i
# 14                                   tô aki no bobs 😍          r
# 15                           to afim de comer no bobs          r
# 16  miga quando eu falo em me levar para o bobs  v...          i
# 17                   comprei aquele milkshake do bobs          r
# 18                             to ino lá no bobs cole          i
# 19                   os gordinho tão aqui no bobs mll          i
# 20                                   lanchei no bobs😋          r
# 21  seu perfil foi visto por 3 pessoas nas últimas...          i
# 22  boa vistense ingrato  fila gigante no bk e zer...          i
# 23  aaaaa aquele dia o rafa trombou comigo no bobs...          i
# 24                                       acho q acord          i
# 25  se a bobs fosse um pouco maos perto do trabalh...          r
# 26                                          bobs e uo          i
# 27                                  franlitos do bobs          i
# 28  vamos sair essa semana aí vc come bk eu como m...          i
# 29  cebola é tão gato que o guarda-sol do bobs se ...          i
# 30                                       eu estudando          i
# 31  e pensar que já tem 4 meses que não to comendo...          i
# 32             indignada q sou enganada até pelo bobs          i
# 33  pronto  pedi um lanche do bobs só assim pra ag...          r
# 34      estou só debobs em casa deitado vendo #usopen          i
# 35  se for por lanche serei eu ne laís   so pelos ...          r

# %%
relevante = dados[dados.relevancia=='r'].Treinamento
irrelevante = dados[dados.relevancia=='i'].Treinamento
relevante
# Out:
# 0                                 bobs é mt ruim  mc&gt
# 1      sonhei com a namorada ideal   rolê  kunk  bobs...
# 4                    tô matando por um milkshake do bobs
# 5      a gnt toma um cafézin vai no bobs compra 770ml...
# 6                    vem me buscar hj q te dou um bobs 😍
# 8           eu queria um milkshake de ovomaltine do bobs
# 10     fica a dúvida  comprar um milkshake no bobs ou...
# 11     as vezes tudo que uma pessoa precisa eh de um ...
# 12            esse milkshake do bobs é o melhor do mundo
# 14                                      tô aki no bobs 😍
# 15                              to afim de comer no bobs
# 17                      comprei aquele milkshake do bobs
# 20                                      lanchei no bobs😋
# 25     se a bobs fosse um pouco maos perto do trabalh...
# 33     pronto  pedi um lanche do bobs só assim pra ag...
# 35     se for por lanche serei eu ne laís   so pelos ...
# 36                eu querendo uns bobs um cineminha afff
# 38            eu e marcelo tamos comendo muito no bobs 😅
# 39     a única coisa decente do bobs é o milk de ovom...
# 41               sdds de um milkshake de morango do bobs
# 42     chatiadissíma por morar no fim do mundo e o bo...
# 43     vou no mc e dps no bobs tomar um milkshake  o ...
# 44     semana toda resumida em mc bobs e pizza alguém...
# 46         tô com muita vontade de um milk shake do bobs
# 47     so um milkshake de ovomaltine do bobs agr   só...
# 50     bobs podia ser do lado da minha casa  só um su...
# 52                          o bobs é melhor n vou mentir
# 55                       quero ir no bobs  sei lá  🤷🏽‍♀️
# 56     bora bida  praça de alimentação do neumarkt é ...
# 57                            bobs burgers supera tudo ✌
#                              ...
# 214                           vem tomar milk no bobs 😌❤️
# 218          se ela fala sv  vou levar ela lá no bobs ❤✌
# 219    saudade mesmo é o que eu tô sentindo daquele b...
# 220    se eu tivesse dinheiro ia ali no bobs agora so...
# 225    essa batata canoa do bobs com chili e cheddar ...
# 228    bobs tem gosto de vomito dsclp e pepsi free re...
# 229    eu num quero ir p academia hj naun  eu quero i...
# 231    achei que fosse demorar séculos que nem o bobs...
# 232                                          bobs é ruim
# 233    o tanto que eu ja gastei com bobs      mas val...
# 243    miga tem shopping lá perto pra gente ir  quero...
# 247       pra hoje um milkshake do bobs tava bom pra mim
# 250                    comi bobs e agora to passando mal
# 256    sabe no filme do mcdonalds em q mostra q algum...
# 257                      milkshake do bobs é muito bommm
# 260                                amooo comer no bobs 💖
# 261    as vezes tudo que uma pessoa precisa eh de um ...
# 263                       só um milk shake do bobs agora
# 264    queria muito mesmo um milk shake de nutella do...
# 268    matei a vontade que eu tava do milkshake de ov...
# 269    alguém vai ali no bobs pra mim e compra um mil...
# 270    tomei sorvete do bobs♡e encontrei vários conhe...
# 276                             um bobs cairia bem agora
# 277                       só um milk shake do bobs agora
# 279                    o que é aquele milk shake do bobs
# 285       pelo menos sexta depois do aula eu vou no bobs
# 286              sdds de um milkshake de morango do bobs
# 287                    bobs burgues eh bom demais mermao
# 291                vou lá no bobs comprar um milkshake 🤤
# 298    tadinha da mina que passou fome comendo bobs t...
# Name: Treinamento, Length: 122, dtype: object

# %%
rel = []
for msg in relevante:
    palavras = msg.split()
    for x in palavras:
        rel.append(x)
r = pd.DataFrame({"Treinamento":rel}).Treinamento.value_counts()/len(rel)*100


irrel = []
for msg in irrelevante:
    palavras = msg.split()
    for x in palavras:
        irrel.append(x)
ir = pd.DataFrame({"Treinamento":irrel}).Treinamento.value_counts()/len(irrel)*100

# %%
j=0
k=0
for i in dados.relevancia:
    if i=='r':
        k+=1
    if i=='i':
        j+=1
        
k=(k/len(dados.relevancia)) *100
j=(j/len(dados.relevancia))*100

k
# Out:
# 40.666666666666664

# %%
palav=[]
for a in rel:
    for b in irrel:
        if a!= b:
            if a not in palav:
                palav.append(a)
            if b not in palav:
                palav.append(b)

# %%
rele = []
for msg in relevante:
    palavras = msg.split()
    for x in palavras:
        rele.append(x)
re = pd.DataFrame({"Treinamento":rele}).Treinamento.value_counts()

relevan={}
x=[]
for a in rele:
    if a not in x:
        t=(re[a]+1)/(len(rele)+len(palav))
        relevan[a]=t*100
        x.append(a)        


irrele = []
for msg in irrelevante:
    palavras = msg.split()
    for x in palavras:
        irrele.append(x)
irre = pd.DataFrame({"Treinamento":irrele}).Treinamento.value_counts()
irrelevan={}
x=[]
for a in irrele:
    if a not in x:
        t=(irre[a]+1)/(len(irrele)+len(palav))
        irrelevan[a]=t*100
        x.append(a)

# %%
for i in range(len(teste)):
    caract=[',',';','.','!','?',"(",")", ':', '"', "'"]
    palavras = teste.Teste[i].split()
    palavrascerto=[]
    final=[]
    for x in palavras:
        lista=[]
        for a in range(len(x)):
            lista.append(x[a])
            
        palavrascerto.append(lista)

    for z in palavrascerto:
        for w in z:
            if w in caract:

                d=z.index(w)
                z[d] = ' '
    for q in range(len(palavrascerto)):
        junto = ''.join(palavrascerto[q])
        if len(junto)!=0:
            if junto[0] !='@' and junto[0:5]!='https' and junto!= 'rt' and junto[0:3]!='kkk':
                final.append(junto)
    deletar=[]            
    for a in range(len(final)):
        if final[a]=='de'and final[a+1]=='bobs':
            deletar.append(a)
    for m in deletar:
        del final[m]
        final[m]='debobs'             
            
    teste.Teste[i] = ' '.join(final)
teste.head(36)
# Out:
#                                                 Teste Manual EspManual  \
# 0    só um lanche do bobs ric ou coelho na minha vida      i         n
# 1        nos foi no bobs e ainda comemos uma pizza 🍕👫      i         i
# 2   minha mãe foi pro shopping e trouxe um lanche ...      r         r
# 3   eu e neandro deixando cair o bglh de julia no ...      i        mi
# 4      que victor que vc vai no bobs — santos ❤ amigo      i        mi
# 5   criando forças p levantar e ir no bobs comer a...      i         i
# 6                                         boa tarde ☉      i        mi
# 7   minha mae ficou com pena de mim e mandou eu cm...      i         n
# 8   acabei de ver q o big cascão tá 2 50 pelo bobs...      i         n
# 9   cheguei no topo do pinheirinho tava tudo sujo ...      i         i
# 10        pra n ter nenhum tipo de contato com a bobs      i        mi
# 11           debobs tomando um mate nesse aniversário      i        mi
# 12  bobs é caro mas se vc pegar a promo é bem show...      r        mr
# 13  ser de câncer não é fácil senhor fico 2 debobs...      i        mi
# 14  o malza ultando no trundle imagina aqueles mil...      i         n
# 15  valentina e andreina dividindo a cartela de pr...      i         i
# 16                tava com a luara e o lucas no bobs❤      i         i
# 17             eu querendo uns bobs um cineminha afff      i         i
# 18  acabei de comer um x-tudo com o mik shake do b...      r        mr
# 19  ter um lanche do bobs quando vc acorda na sua ...      r        mr
# 20                     principalmente a parte do bobs      i        mi
# 21  ri n desgraçado é ruim p todo mundo bora xinga...      i        mi
# 22                            tô no bobs com o felipe      i         i
# 23                eu to no bobs com a feh e a gabi😂😂😂      i         i
# 24  de tanto sabor no bobs pra escolher eu peguei ...      i         n
# 25  #setiverguerraeu vou correr ate o bobs e prepa...      i         n
# 26      tô com muita vontade de um milk shake do bobs      r        mr
# 27                 melhor de ontem foi o bobs namoral      i         i
# 28  manoo como queria ter comido um bobs na moral ...      r         r
# 29  fui na paquera lopes pq estava com peso na con...      i         i
# 30              bobs japa cerveja projeto seu barriga      i         i
# 31                           esse bk tá mais pra bobs      r         n
# 32  eu só queria alguém pra ir tomar milkshake com...      i         n
# 33         no momento desejando um milk shake do bobs      r        mr
# 34  acho graça desse nerd querer falar das minas o...      i        mi
# 35                                             debobs      i        mi
#
#             dif Digital Especifico
# 0   -6.5104e-10       i         mi
# 1  -2.50141e-10       i         mi
# 2  -2.85271e-14       i          i
# 3   -6.5504e-18       i          i
# 4   8.61026e-15       r          r
# 5  -5.28779e-11       i          i
# 6   0.000225574       r         mr
# 7    -1.542e-11       i          i
# 8  -2.25953e-16       i          i
# 9   7.81726e-29       r          n
# 10 -2.12862e-11       i          i
# 11  2.15144e-13       r          r
# 12 -2.18065e-19       i          i
# 13 -4.86548e-49       i          n
# 14  1.53373e-29       r          n
# 15  2.01143e-18       r          r
# 16  -0.00103383       i         mi
# 17    0.0252836       r         mr
# 18  3.82176e-12       r          r
# 19 -9.40712e-18       i          i
# 20 -0.000727391       i         mi
# 21   5.0404e-24       r          n
# 22    -0.476344       i         mi
# 23 -1.29803e-06       i         mi
# 24  5.56511e-09       r         mr
# 25 -4.50831e-14       i          i
# 26       19.484       r         mr
# 27  -0.00271116       i         mi
# 28 -1.69101e-21       i          n
# 29 -9.99682e-32       i          n
# 30  1.43148e-10       r         mr
# 31     0.818356       r         mr
# 32  6.25688e-13       r          r
# 33      30.7268       r         mr
# 34 -1.29035e-46       i          n
# 35     -2.30288       i         mi

# %%
teste.loc[: , 'dif']='x'
teste.loc[: , 'Digital']='z'
for i in range(len(teste)):
    palavras = teste.Teste[i].split()
    probr =k
    probir=j
    x='sim'
    for l in palavras:
        if l not in r:
            x='nao'
        if l not in ir:
            x='nao'
    if x =='sim':
        for q in palavras:
            probr*=r[q]
            probir*=ir[q]
    else: 
        for q in palavras:
            if q in relevan:
                probr*=relevan[q]
            else:
                probr*=1/(len(rele)+len(palav))
            if q in irrelevan:    
                probir*= irrelevan[q]
            else:
                probir*= 1/(len(irrele)+len(palav))
    if probr> probir:
        teste.Digital[i]='r'
    else:
        teste.Digital[i]='i'       
    probdifR=probr-probir
    
    teste.dif[i]=probdifR
teste.loc[teste.dif < - (10**(-10)), 'Especifico']='mi'
teste.loc[teste.dif > - (10**(-10)), 'Especifico']='i'
teste.loc[teste.dif > - (10**(-20)), 'Especifico']='n'
teste.loc[teste.dif >  (10**(-20)), 'Especifico']='r'
teste.loc[teste.dif >  (10**(-10)), 'Especifico']='mr'
teste.head(36)
# Out:
#                                                 Teste Manual EspManual  \
# 0   só um lanche do bobs  ric ou coelho na minha vida      i         n
# 1        nos foi no bobs e ainda comemos uma pizza 🍕👫      i         i
# 2   minha mãe foi pro shopping e trouxe um lanche ...      r         r
# 3   eu e neandro deixando cair o bglh de julia no ...      i        mi
# 4   que victor que vc vai no bobs   — santos ❤ amigo       i        mi
# 5   criando forças p levantar e ir no bobs comer a...      i         i
# 6                                         boa tarde ☉      i        mi
# 7   minha mae ficou com pena de mim e mandou eu cm...      i         n
# 8   acabei de ver q o big cascão tá 2 50 pelo bobs...      i         n
# 9   cheguei no topo do pinheirinho tava tudo sujo ...      i         i
# 10        pra n ter nenhum tipo de contato com a bobs      i        mi
# 11           debobs tomando um mate nesse aniversário      i        mi
# 12  bobs é caro mas se vc pegar a promo é bem show...      r        mr
# 13  ser de câncer não é fácil senhor  fico 2 debob...      i        mi
# 14  o malza ultando no trundle  imagina aqueles mi...      i         n
# 15  valentina e andreina dividindo a cartela de pr...      i         i
# 16                tava com a luara e o lucas no bobs❤      i         i
# 17             eu querendo uns bobs um cineminha afff      i         i
# 18  acabei de comer um x-tudo com o mik shake do b...      r        mr
# 19  ter um lanche do bobs quando vc acorda na sua ...      r        mr
# 20                     principalmente a parte do bobs      i        mi
# 21  ri n  desgraçado  é ruim p todo mundo  bora xi...      i        mi
# 22                            tô no bobs com o felipe      i         i
# 23                eu to no bobs com a feh e a gabi😂😂😂      i         i
# 24  de tanto sabor no bobs pra escolher eu peguei ...      i         n
# 25  #setiverguerraeu vou correr ate o bobs e prepa...      i         n
# 26      tô com muita vontade de um milk shake do bobs      r        mr
# 27                melhor de ontem foi o bobs  namoral      i         i
# 28  manoo  como queria ter comido um bobs  na mora...      r         r
# 29  fui na paquera lopes pq estava com peso na con...      i         i
# 30         bobs  japa  cerveja    projeto seu barriga      i         i
# 31                           esse bk tá mais pra bobs      r         n
# 32  eu só queria alguém pra ir tomar milkshake com...      i         n
# 33         no momento desejando um milk shake do bobs      r        mr
# 34  acho graça desse nerd querer falar das minas  ...      i        mi
# 35                                             debobs      i        mi
#
#             dif Digital Especifico
# 0   -6.5104e-10       i         mi
# 1  -2.50141e-10       i         mi
# 2  -2.85271e-14       i          i
# 3   -6.5504e-18       i          i
# 4   8.61026e-15       r          r
# 5  -5.28779e-11       i          i
# 6   0.000225574       r         mr
# 7    -1.542e-11       i          i
# 8  -2.25953e-16       i          i
# 9   7.81726e-29       r          n
# 10 -2.12862e-11       i          i
# 11  2.15144e-13       r          r
# 12 -2.18065e-19       i          i
# 13 -4.86548e-49       i          n
# 14  1.53373e-29       r          n
# 15  2.01143e-18       r          r
# 16  -0.00103383       i         mi
# 17    0.0252836       r         mr
# 18  3.82176e-12       r          r
# 19 -9.40712e-18       i          i
# 20 -0.000727391       i         mi
# 21   5.0404e-24       r          n
# 22    -0.476344       i         mi
# 23 -1.29803e-06       i         mi
# 24  5.56511e-09       r         mr
# 25 -4.50831e-14       i          i
# 26       19.484       r         mr
# 27  -0.00271116       i         mi
# 28 -1.69101e-21       i          n
# 29 -9.99682e-32       i          n
# 30  1.43148e-10       r         mr
# 31     0.818356       r         mr
# 32  6.25688e-13       r          r
# 33      30.7268       r         mr
# 34 -1.29035e-46       i          n
# 35     -2.30288       i         mi

# %% [markdown]
# ___
# ## Verificando a performance
#
# Agora você deve testar o seu Classificador com a base de Testes.<br /><br />
#
# Você deve extrair as seguintes medidas:
# * Porcentagem de positivos falsos (marcados como relevante mas não são relevantes)
# * Porcentagem de positivos verdadeiros (marcado como relevante e são relevantes)
# * Porcentagem de negativos verdadeiros (marcado como não relevante e não são relevantes)
# * Porcentagem de negativos falsos (marcado como não relevante e são relevantes)
#
# Opcionalmente:
# * Criar categorias intermediárias de relevância baseado na diferença de probabilidades. Exemplo: muito relevante, relevante, neutro, irrelevante e muito irrelevante.

# %%
pf=0
pv=0
nv=0
nf=0
for i in range(len(teste.Digital)):
    if teste.Digital[i] == 'i':
        if teste.Manual[i] == 'i':
            nv+=1
            
        else:
            nf+=1
    if teste.Digital[i] == 'r':
        if teste.Manual[i] == 'r':
            pv+=1
        else:
            pf+=1
pf=(pf/len(teste.Digital))*100
pv=(pv/len(teste.Digital))*100
nv=(nv/len(teste.Digital))*100
nf=(nf/len(teste.Digital))*100



print(pf,pv,nv,nf)
# Out:
# 18.5 18.0 52.0 11.5

# %%
lista=['mr','mi','n','r','i']
dic={}

for o in lista:
    dic[o]=0
for o in lista:
    for j in range(len(lista)):
        dic[o+lista[j]]=0
        
for i in range(len(teste.EspManual)):
        if teste.Especifico[i] == teste.EspManual[i]:
            dic[teste.Especifico[i]]=dic[teste.Especifico[i]]+1
        else:
            dic[teste.EspManual[i]+teste.Especifico[i]]=dic[teste.Especifico[i]+teste.EspManual[i]]+1
deletar=[]
for i in dic:
    if dic[i]==0:
        deletar.append(i)
for i in deletar:
    del(dic[i])
print(dic)
for i in dic:
    dic[i]=(dic[i]/len(teste.Especifico))*100
print()
print(dic)
# Out:
# {'mr': 15, 'mi': 14, 'n': 5, 'i': 6, 'mrmi': 2, 'mrn': 2, 'mrr': 5, 'mri': 9, 'mimr': 3, 'min': 20, 'mir': 4, 'mii': 18, 'nmr': 1, 'nmi': 19, 'nr': 5, 'ni': 11, 'rmr': 6, 'rmi': 5, 'rn': 4, 'ri': 3, 'imr': 10, 'imi': 19, 'in': 10, 'ir': 4}
#
# {'mr': 7.5, 'mi': 7.000000000000001, 'n': 2.5, 'i': 3.0, 'mrmi': 1.0, 'mrn': 1.0, 'mrr': 2.5, 'mri': 4.5, 'mimr': 1.5, 'min': 10.0, 'mir': 2.0, 'mii': 9.0, 'nmr': 0.5, 'nmi': 9.5, 'nr': 2.5, 'ni': 5.5, 'rmr': 3.0, 'rmi': 2.5, 'rn': 2.0, 'ri': 1.5, 'imr': 5.0, 'imi': 9.5, 'in': 5.0, 'ir': 2.0}

# %%
p = teste.Especifico.value_counts(True)*100
p
# Out:
# mi    26.5
# mr    24.0
# i     23.5
# n     19.0
# r      7.0
# Name: Especifico, dtype: float64

# %% [markdown]
# ___
# ## Concluindo
#
# Escreva aqui a sua conclusão.<br />
# Faça um comparativo qualitativo sobre as medidas obtidas.<br />
# Explique como são tratadas as mensagens com dupla negação e sarcasmo.<br />
# Proponha um plano de expansão. Por que eles devem continuar financiando o seu projeto?<br />
#
# Opcionalmente:
# * Discorrer por que não posso alimentar minha base de Treinamento automaticamente usando o próprio classificador, aplicado a novos tweets.
# * Propor diferentes cenários de uso para o classificador Naive-Bayes. Cenários sem intersecção com este projeto.
# * Sugerir e explicar melhorias reais no classificador com indicações concretas de como implementar (não é preciso codificar, mas indicar como fazer e material de pesquisa sobre o assunto).
